# %% [markdown]
# # uv Environment & git Repository

# %% [markdown]
# This notebook is meant to manipulate a git repo with [`uv`](https://docs.astral.sh/uv/) installed to handle dependencies.
#
# Enter the git repository URL:

# %%
url = "https://github.com/shuuchuu/..."

# %% [markdown]
# Then, run this cell:

# %%
from pathlib import Path

# %pip install -U uv
# %cd /content
# !rm -rf sample_data .config
# !git clone {url}
folder = next(iter(p for p in Path("/content").iterdir() if p.is_dir()))
# %cd {folder}
